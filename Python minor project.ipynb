# %%
import pandas as pd 
import numpy as np

# %%
file = pd.read_csv("M:/faiz/csvfile.csv")

# %%
file.head(5)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# ...

# %%
file.shape
# Out:
# (10127, 21)

# %%
file.isnull().sum()/100
# Out:
# CLIENTNUM                   0.0
# Attrition_Flag              0.0
# Customer_Age                0.0
# Gender                      0.0
# Dependent_count             0.0
# Education_Level             0.0
# Marital_Status              0.0
# Income_Category             0.0
# Card_Category               0.0
# Months_on_book              0.0
# Total_Relationship_Count    0.0
# Months_Inactive_12_mon      0.0
# Contacts_Count_12_mon       0.0
# Credit_Limit                0.0
# Total_Revolving_Bal         0.0
# Avg_Open_To_Buy             0.0
# Total_Amt_Chng_Q4_Q1        0.0
# Total_Trans_Amt             0.0
# Total_Trans_Ct              0.0
# Total_Ct_Chng_Q4_Q1         0.0
# Avg_Utilization_Ratio       0.0
# dtype: float64

# %%
file.duplicated().any()
# Out:
# False

# %%
customer_age_distribution = df['Customer_Age'].value_counts()

# %%
file['Customer_Age'].value_counts().sum()
# Out:
# 10127

# %%
file['Customer_Age'].mean()
# Out:
# 46.32596030413745

# %%
file['Customer_Age'].median()
# Out:
# 46.0

# %%
file['Customer_Age'].std()
# Out:
# 8.016814032549084

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x=file['Gender'], y = file['Months_on_book'])
plt.title('Box Plot of Customer Age')
plt.xlabel('Customer Age')
plt.ylabel('Months on book')
plt.show()

# %%
gender_perc = file['Gender'].value_counts()
plt.figure(figsize=(4, 4))
plt.pie(gender_counts, labels=gender_perc.index, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral'])
plt.title('HOW MANY % OF MALES AND FEMALES ARE THERE')
plt.show()

# %%
gender_counts = file[['Gender','Education_Level']].value_counts()
colors = ['yellow','pink']
plt.figure(figsize=(10, 10))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', colors=colors)
plt.title('Gender Distribution acc to educaitonal level')
plt.show()

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(10, 8))
sns.boxplot(x='Attrition_Flag', y='Total_Revolving_Bal', hue='Card_Category', data=file, palette='viridis')
plt.title('Box Plot of Total_Revolving_Bal and Card_Category by Attrition_Flag')
plt.xlabel('Attrition_Flag')
plt.ylabel('Total_Revolving_Bal')
plt.legend(title='Card_Category', loc='upper right')
plt.show()

# %%
sns.set(style='whitegrid')
ed_percentage = file.groupby(['Education_Level', 'Attrition_Flag']).size().unstack(fill_value=0)
ed_attr_percentage = ed_attr_percentage.div(ed_attr_percentage.sum(axis=1), axis=0) * 100
plt.figure(figsize=(12, 8))
ed_attr_percentage.plot(kind='bar', stacked=True, colormap='viridis')
plt.title('Percentage Segmented Bar Graph between Education_Level and Attrition_Flag')
plt.xlabel('Education_Level')
plt.ylabel('Percentage')
plt.legend(title='Attrition_Flag', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
income_attrition_percentage = file.groupby(['Income_Category', 'Attrition_Flag']).size().unstack(fill_value=0)
income_attrition_percentage = income_attrition_percentage.div(income_attrition_percentage.sum(axis=1), axis=0) * 100
sns.set(style='whitegrid')
plt.figure(figsize=(12, 8))
income_attrition_percentage.plot(kind='bar', stacked=True, colormap='Set2')
plt.title('Percentage Segmented Bar Graph between Income_Category and Attrition_Flag')
plt.xlabel('Income_Category')
plt.ylabel('Percentage')
plt.legend(title='Attrition_Flag', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
file.dtypes
# Out:
# CLIENTNUM                     int64
# Attrition_Flag               object
# Customer_Age                  int64
# Gender                       object
# Dependent_count               int64
# Education_Level              object
# Marital_Status               object
# Income_Category              object
# Card_Category                object
# Months_on_book                int64
# Total_Relationship_Count      int64
# Months_Inactive_12_mon        int64
# Contacts_Count_12_mon         int64
# Credit_Limit                float64
# Total_Revolving_Bal           int64
# Avg_Open_To_Buy             float64
# Total_Amt_Chng_Q4_Q1        float64
# Total_Trans_Amt               int64
# Total_Trans_Ct                int64
# Total_Ct_Chng_Q4_Q1         float64
# Avg_Utilization_Ratio       float64
# dtype: object

# %%
numeric_c = file.select_dtypes(include=['float', 'int'])
numeric_c.head(2)
# Out:
#    CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# 0  768805383            45                3              39
# 1  818770008            49                5              44
#
#    Total_Relationship_Count  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0                         5                       1                      3
# 1                         6                       1                      2
#
#    Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  \
# 0       12691.0                  777          11914.0                 1.335
# 1        8256.0                  864           7392.0                 1.541
#
#    Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# 0             1144              42                1.625                  0.061
# 1             1291              33                3.714                  0.105

# %%
column_to_drop = 'CLIENTNUM'

numeric_C = numeric_c.drop(columns=column_to_drop)

# %%
numeric_C = numeric_C.join(file['Attrition_Flag'])

# %%
numeric_C.corr().head(4)
# Out:
#                           Customer_Age  Dependent_count  Months_on_book  \
# Customer_Age                  1.000000        -0.122254        0.788912
# Dependent_count              -0.122254         1.000000       -0.103062
# Months_on_book                0.788912        -0.103062        1.000000
# Total_Relationship_Count     -0.010931        -0.039076       -0.009203
#
#                           Total_Relationship_Count  Months_Inactive_12_mon  \
# Customer_Age                             -0.010931                0.054361
# Dependent_count                          -0.039076               -0.010768
# Months_on_book                           -0.009203                0.074164
# Total_Relationship_Count                  1.000000               -0.003675
#
#                           Contacts_Count_12_mon  Credit_Limit  \
# Customer_Age                          -0.018452      0.002476
# Dependent_count                       -0.040505      0.068065
# ...

# %%
plt.figure(figsize=(14, 6))
sns.heatmap(numeric_C.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10, 4))
sns.boxplot(x=numeric_C['Credit_Limit'])
plt.title('Boxplot for Credit_Limit')
plt.xlabel('Credit_Limit')
plt.show()

# %%
numeric_C['Attrition_Flag'] = numeric_C['Attrition_Flag'].map({'Existing Customer': 0, 'Attrited Customer': 1})

# %%
numeric_C['Attrition_Flag']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 10122   NaN
# 10123   NaN
# 10124   NaN
# 10125   NaN
# 10126   NaN
# Name: Attrition_Flag, Length: 10127, dtype: float64

# %%
from sklearn.preprocessing import LabelEncoder

# Use LabelEncoder to map Attrition_Flag to 0 and 1
label_encoder = LabelEncoder()
file['Attrition_Flag'] = label_encoder.fit_transform(file['Attrition_Flag'])

print(file['Attrition_Flag'])
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 10122    1
# 10123    0
# 10124    0
# 10125    0
# 10126    0
# Name: Attrition_Flag, Length: 10127, dtype: int32
